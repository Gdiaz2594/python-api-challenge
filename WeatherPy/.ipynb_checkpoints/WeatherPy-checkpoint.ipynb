# %% [markdown]
# # WeatherPy
# ---

# %% [markdown]
# #### Analysis
# Accordding to the plots and all the data found I can conclude that:
# * When closer to the Ecuator the temperature is gratter and as you get further from the Ecuator it gets colder.
# * When further from the Ecuator in the norther hemisphere the humidity increases, but in the southern hemisphere the humidity is very diverse no matter the latitude.
# * When further from the Ecuator the wind speed tens to be bigger in both hemispheres.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List
# ---

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ## Perform API Calls
#
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&q="

# %%
# Print log of each city as it'sbeing processed
record = 0
set_num = 1
cities_with_data = []
print("""-----------------------------------
Beginning Data Retrieval 
-----------------------------------""")
for city in cities:
    city_url = f"{url}{city}&units=imperial"
    response = requests.get(city_url).json()
    try:
        city_name = response["name"]
        city_id = response["id"]
        print(f"Record {str(record)} of set {str(set_num)} | City number: {city_id} City name: {city_name}")
        cities_with_data.append(city) #list of the cities that have data
    except:
        print(f"{city} not found. Skipping..")
    record += 1
    if record == 50:
        set_num +=1
        record = 0
print("""-----------------------------------
Data Retrieval Complete
-----------------------------------""")
# Out:
# -----------------------------------
# Beginning Data Retrieval
# -----------------------------------
# Record 0 of set 1 | City number: 3833367 City name: Ushuaia
# Record 1 of set 1 | City number: 1344069 City name: Contai
# amderma not found. Skipping..
# Record 3 of set 1 | City number: 1651810 City name: Airai
# Record 4 of set 1 | City number: 546105 City name: Nikolskoye
# Record 5 of set 1 | City number: 1266806 City name: Khedbrahma
# Record 6 of set 1 | City number: 1015776 City name: Bredasdorp
# Record 7 of set 1 | City number: 2120048 City name: Ust-Nera
# Record 8 of set 1 | City number: 933995 City name: Souillac
# Record 9 of set 1 | City number: 6201424 City name: Mataura
# Record 10 of set 1 | City number: 3412093 City name: Vestmannaeyjar
# Record 11 of set 1 | City number: 2206939 City name: Bluff
# Record 12 of set 1 | City number: 5106841 City name: Albany
# Record 13 of set 1 | City number: 3366880 City name: Hermanus
# Record 14 of set 1 | City number: 2264557 City name: Ponta do Sol
# Record 15 of set 1 | City number: 964432 City name: Port Alfred
# Record 16 of set 1 | City number: 3471451 City name: Arraial do Cabo
# Record 17 of set 1 | City number: 2163355 City name: Hobart
# Record 18 of set 1 | City number: 3408424 City name: Ipixuna
# Record 19 of set 1 | City number: 3533462 City name: Acapulco de Juárez
# Record 20 of set 1 | City number: 286621 City name: Salalah
# Record 21 of set 1 | City number: 4030556 City name: Rikitea
# mys shmidta not found. Skipping..
# Record 23 of set 1 | City number: 4032243 City name: Vaini
# Record 24 of set 1 | City number: 98182 City name: Baghdad
# Record 25 of set 1 | City number: 2126710 City name: Beringovskiy
# sug-aksy not found. Skipping..
# taolanaro not found. Skipping..
# Record 28 of set 1 | City number: 3421765 City name: Nanortalik
# Record 29 of set 1 | City number: 155274 City name: Mahenge
# Record 30 of set 1 | City number: 5848280 City name: Kapaa
# Record 31 of set 1 | City number: 2129868 City name: Iwanai
# Record 32 of set 1 | City number: 2132606 City name: Samarai
# Record 33 of set 1 | City number: 4726521 City name: San Patricio
# Record 34 of set 1 | City number: 779622 City name: Havøysund
# Record 35 of set 1 | City number: 3874787 City name: Punta Arenas
# Record 36 of set 1 | City number: 513329 City name: Ozinki
# Record 37 of set 1 | City number: 3883457 City name: Lebu
# Record 38 of set 1 | City number: 5955902 City name: Fort Nelson
# Record 39 of set 1 | City number: 1250161 City name: Batticaloa
# Record 40 of set 1 | City number: 5880054 City name: Barrow
# Record 41 of set 1 | City number: 5122534 City name: Jamestown
# Record 42 of set 1 | City number: 2715459 City name: Falun
# Record 43 of set 1 | City number: 3386931 City name: Tamandaré
# Record 44 of set 1 | City number: 1701054 City name: Marawi
# Record 45 of set 1 | City number: 4035715 City name: Avarua
# Record 46 of set 1 | City number: 5882953 City name: Aklavik
# Record 47 of set 1 | City number: 6167817 City name: Torbay
# Record 48 of set 1 | City number: 5354943 City name: Half Moon Bay
# belushya guba not found. Skipping..
# Record 0 of set 2 | City number: 3873145 City name: Río Bueno
# samusu not found. Skipping..
# Record 2 of set 2 | City number: 367644 City name: Sennar
# Record 3 of set 2 | City number: 2963295 City name: Killybegs
# Record 4 of set 2 | City number: 3418910 City name: Upernavik
# Record 5 of set 2 | City number: 5847486 City name: Kailua
# Record 6 of set 2 | City number: 2025256 City name: Chumikan
# Record 7 of set 2 | City number: 3430863 City name: Mar del Plata
# Record 8 of set 2 | City number: 3466704 City name: Castro
# Record 9 of set 2 | City number: 5847411 City name: Kahului
# Record 10 of set 2 | City number: 4020109 City name: Atuona
# Record 11 of set 2 | City number: 3372707 City name: Ribeira Grande
# Record 12 of set 2 | City number: 964420 City name: Port Elizabeth
# Record 13 of set 2 | City number: 5855927 City name: Hilo
# Record 14 of set 2 | City number: 3530103 City name: San Miguel de Cozumel
# Record 15 of set 2 | City number: 2194098 City name: Ahipara
# Record 16 of set 2 | City number: 2412408 City name: Nioro
# Record 17 of set 2 | City number: 3471896 City name: Aquidauana
# Record 18 of set 2 | City number: 777682 City name: Skjervøy
# Record 19 of set 2 | City number: 1282256 City name: Hithadhoo
# Record 20 of set 2 | City number: 1507390 City name: Dikson
# Record 21 of set 2 | City number: 3443061 City name: Chui
# halalo not found. Skipping..
# Record 23 of set 2 | City number: 3372964 City name: Lagoa
# Record 24 of set 2 | City number: 4034551 City name: Faanui
# Record 25 of set 2 | City number: 1899102 City name: Nagato
# Record 26 of set 2 | City number: 3347019 City name: Mossamedes
# Record 27 of set 2 | City number: 5282297 City name: Bethel
# Record 28 of set 2 | City number: 6137462 City name: Saint-Augustin
# Record 29 of set 2 | City number: 3430545 City name: Morón
# vaitupu not found. Skipping..
# Record 31 of set 2 | City number: 5742974 City name: North Bend
# Record 32 of set 2 | City number: 80509 City name: Al Bardīyah
# Record 33 of set 2 | City number: 3831208 City name: Qaanaaq
# Record 34 of set 2 | City number: 2409914 City name: Bonthe
# Record 35 of set 2 | City number: 3512067 City name: Baní
# Record 36 of set 2 | City number: 2075265 City name: Busselton
# Record 37 of set 2 | City number: 1525798 City name: Balkhash
# Record 38 of set 2 | City number: 3424607 City name: Tasiilaq
# Record 39 of set 2 | City number: 2110227 City name: Butaritari
# Record 40 of set 2 | City number: 6050066 City name: La Ronge
# Record 41 of set 2 | City number: 3020062 City name: Épernay
# Record 42 of set 2 | City number: 482042 City name: Toropets
# Record 43 of set 2 | City number: 3466165 City name: Cidreira
# Record 44 of set 2 | City number: 4617305 City name: Davidson
# Record 45 of set 2 | City number: 3652764 City name: Puerto Ayora
# barentsburg not found. Skipping..
# Record 47 of set 2 | City number: 2641434 City name: Northam
# Record 48 of set 2 | City number: 146400 City name: Dromolaxia
# Record 49 of set 2 | City number: 1253237 City name: Verāval
# Record 0 of set 3 | City number: 6165406 City name: Thompson
# Record 1 of set 3 | City number: 1503153 City name: Klyuchi
# Record 2 of set 3 | City number: 6324729 City name: Halifax
# Record 3 of set 3 | City number: 1789647 City name: Xichang
# Record 4 of set 3 | City number: 3374210 City name: São Filipe
# Record 5 of set 3 | City number: 5803990 City name: Moses Lake
# Record 6 of set 3 | City number: 2450173 City name: Taoudenni
# Record 7 of set 3 | City number: 935215 City name: Saint-Philippe
# Record 8 of set 3 | City number: 1635283 City name: Metro
# Record 9 of set 3 | City number: 2396518 City name: Port-Gentil
# Record 10 of set 3 | City number: 1634614 City name: Nabire
# Record 11 of set 3 | City number: 6255012 City name: Flinders
# Record 12 of set 3 | City number: 6112608 City name: Powell River
# Record 13 of set 3 | City number: 1812256 City name: Dongsheng
# Record 14 of set 3 | City number: 6185377 City name: Yellowknife
# Record 15 of set 3 | City number: 4031574 City name: Provideniya
# Record 16 of set 3 | City number: 1571058 City name: Phan Thiet
# kamenskoye not found. Skipping..
# Record 18 of set 3 | City number: 2155415 City name: New Norfolk
# Record 19 of set 3 | City number: 2017155 City name: Saskylakh
# Record 20 of set 3 | City number: 2515096 City name: Lebrija
# Record 21 of set 3 | City number: 556268 City name: Ostrovnoy
# Record 22 of set 3 | City number: 2143285 City name: Wodonga
# Record 23 of set 3 | City number: 359783 City name: Assiut
# Record 24 of set 3 | City number: 3372760 City name: Praia da Vitória
# Record 25 of set 3 | City number: 3860443 City name: Comodoro Rivadavia
# Record 26 of set 3 | City number: 2127282 City name: Aleksandrovsk-Sakhalinskiy
# Record 27 of set 3 | City number: 5866583 City name: Saint Paul Harbor
# sentyabrskiy not found. Skipping..
# Record 29 of set 3 | City number: 1006984 City name: East London
# Record 30 of set 3 | City number: 4998842 City name: Lapeer
# attawapiskat not found. Skipping..
# Record 32 of set 3 | City number: 5688025 City name: Bismarck
# Record 33 of set 3 | City number: 1163054 City name: Turbat
# Record 34 of set 3 | City number: 2274895 City name: Monrovia
# Record 35 of set 3 | City number: 921786 City name: Mitsamiouli
# Record 36 of set 3 | City number: 1272140 City name: Dwārka
# Record 37 of set 3 | City number: 4074736 City name: Marshall
# Record 38 of set 3 | City number: 3601402 City name: Savannah Bight
# Record 39 of set 3 | City number: 2120591 City name: Tilichiki
# Record 40 of set 3 | City number: 1045114 City name: Inhambane
# Record 41 of set 3 | City number: 2439376 City name: Tahoua
# Record 42 of set 3 | City number: 2640006 City name: Portree
# Record 43 of set 3 | City number: 686090 City name: Asău
# Record 44 of set 3 | City number: 3461425 City name: Ilhabela
# Record 45 of set 3 | City number: 3445026 City name: Vila Velha
# Record 46 of set 3 | City number: 3447597 City name: Sidrolândia
# Record 47 of set 3 | City number: 463355 City name: Zheleznodorozhnyy
# Record 48 of set 3 | City number: 4544383 City name: Okmulgee
# Record 49 of set 3 | City number: 2122605 City name: Okhotsk
# Record 0 of set 4 | City number: 3069900 City name: Němčice nad Hanou
# Record 1 of set 4 | City number: 3175096 City name: Laas
# Record 2 of set 4 | City number: 3369157 City name: Cape Town
# Record 3 of set 4 | City number: 2012780 City name: Zabaykal'sk
# Record 4 of set 4 | City number: 2426240 City name: Pala
# Record 5 of set 4 | City number: 561698 City name: Gayny
# Record 6 of set 4 | City number: 5924351 City name: Clyde River
# wahran not found. Skipping..
# Record 8 of set 4 | City number: 627907 City name: Gomel
# Record 9 of set 4 | City number: 2138555 City name: Poum
# fevralsk not found. Skipping..
# Record 11 of set 4 | City number: 613065 City name: Martvili
# Record 12 of set 4 | City number: 1485627 City name: Yuzhnyy
# Record 13 of set 4 | City number: 1855540 City name: Naze
# Record 14 of set 4 | City number: 6943488 City name: Causapscal
# Record 15 of set 4 | City number: 6170031 City name: Tuktoyaktuk
# Record 16 of set 4 | City number: 779554 City name: Honningsvåg
# Record 17 of set 4 | City number: 2094342 City name: Kavieng
# Record 18 of set 4 | City number: 4031742 City name: Egvekinot
# Record 19 of set 4 | City number: 3421193 City name: Paamiut
# Record 20 of set 4 | City number: 3359736 City name: Vredendal
# Record 21 of set 4 | City number: 2121385 City name: Severo-Kuril'sk
# Record 22 of set 4 | City number: 1642773 City name: Japura
# Record 23 of set 4 | City number: 3884373 City name: La Serena
# Record 24 of set 4 | City number: 894701 City name: Bulawayo
# touliu not found. Skipping..
# Record 26 of set 4 | City number: 2178753 City name: Kirakira
# Record 27 of set 4 | City number: 3406457 City name: Baraúna
# Record 28 of set 4 | City number: 2112309 City name: Katsuura
# Record 29 of set 4 | City number: 527012 City name: Mikhaylovka
# Record 30 of set 4 | City number: 5262596 City name: Menasha
# Record 31 of set 4 | City number: 2276492 City name: Harper
# Record 32 of set 4 | City number: 935255 City name: Sainte-Marie
# Record 33 of set 4 | City number: 934322 City name: Mahébourg
# Record 34 of set 4 | City number: 2094144 City name: Kerema
# Record 35 of set 4 | City number: 5557293 City name: Sitka
# haibowan not found. Skipping..
# Record 37 of set 4 | City number: 2077895 City name: Alice Springs
# Record 38 of set 4 | City number: 1274641 City name: Channapatna
# Record 39 of set 4 | City number: 3832899 City name: Viedma
# Record 40 of set 4 | City number: 2122090 City name: Pevek
# Record 41 of set 4 | City number: 4997191 City name: Ionia
# Record 42 of set 4 | City number: 1106677 City name: Bambous Virieux
# Record 43 of set 4 | City number: 2980080 City name: Saint-François
# bolungarvik not found. Skipping..
# Record 45 of set 4 | City number: 377472 City name: Bentiu
# Record 46 of set 4 | City number: 5983720 City name: Iqaluit
# Record 47 of set 4 | City number: 777019 City name: Vardø
# Record 48 of set 4 | City number: 2033675 City name: Xinmin
# Record 49 of set 4 | City number: 5850554 City name: Makakilo City
# Record 0 of set 5 | City number: 6355222 City name: Yulara
# Record 1 of set 5 | City number: 2144764 City name: Wangaratta
# Record 2 of set 5 | City number: 1486321 City name: Yar-Sale
# Record 3 of set 5 | City number: 2137773 City name: Vao
# Record 4 of set 5 | City number: 567589 City name: Chupa
# Record 5 of set 5 | City number: 2446796 City name: Bilma
# Record 6 of set 5 | City number: 3838859 City name: Río Gallegos
# Record 7 of set 5 | City number: 57000 City name: Hobyo
# Record 8 of set 5 | City number: 119374 City name: Qeshm
# Record 9 of set 5 | City number: 3160630 City name: Borkenes
# Record 10 of set 5 | City number: 314967 City name: Fethiye
# Record 11 of set 5 | City number: 1283285 City name: Jumla
# Record 12 of set 5 | City number: 6690297 City name: Saint-Leu
# Record 13 of set 5 | City number: 1489401 City name: Toora-Khem
# Record 14 of set 5 | City number: 122285 City name: Neyshabur
# Record 15 of set 5 | City number: 2221513 City name: Tignère
# Record 16 of set 5 | City number: 1505991 City name: Igarka
# Record 17 of set 5 | City number: 1649150 City name: Bengkulu
# Record 18 of set 5 | City number: 737021 City name: Zonguldak
# Record 19 of set 5 | City number: 5969025 City name: Haines Junction
# grand river south east not found. Skipping..
# Record 21 of set 5 | City number: 2126123 City name: Chokurdakh
# Record 22 of set 5 | City number: 2063036 City name: Port Lincoln
# Record 23 of set 5 | City number: 1714733 City name: Dingle
# palabuhanratu not found. Skipping..
# Record 25 of set 5 | City number: 2392204 City name: Parakou
# Record 26 of set 5 | City number: 2514651 City name: Los Llanos de Aridane
# louisbourg not found. Skipping..
# Record 28 of set 5 | City number: 3449749 City name: Santa Vitória
# Record 29 of set 5 | City number: 517144 City name: Novyye Gorki
# Record 30 of set 5 | City number: 2015306 City name: Tiksi
# Record 31 of set 5 | City number: 3904906 City name: Santa Cruz de la Sierra
# Record 32 of set 5 | City number: 1218436 City name: Saýat
# Record 33 of set 5 | City number: 187585 City name: Marsabit
# Record 34 of set 5 | City number: 2065594 City name: Mount Isa
# Record 35 of set 5 | City number: 3573374 City name: The Valley
# Record 36 of set 5 | City number: 1244926 City name: Hambantota
# Record 37 of set 5 | City number: 2125711 City name: Esso
# Record 38 of set 5 | City number: 5962442 City name: Goderich
# Record 39 of set 5 | City number: 3893629 City name: Coquimbo
# Record 40 of set 5 | City number: 1626703 City name: Soe
# Record 41 of set 5 | City number: 2381334 City name: Atar
# Record 42 of set 5 | City number: 3985710 City name: Cabo San Lucas
# Record 43 of set 5 | City number: 1524889 City name: Chardara
# Record 44 of set 5 | City number: 1728091 City name: Balingasay
# Record 45 of set 5 | City number: 8079926 City name: Labuhan
# Record 46 of set 5 | City number: 3379316 City name: Lethem
# Record 47 of set 5 | City number: 5975034 City name: High Prairie
# Record 48 of set 5 | City number: 5746545 City name: Portland
# Record 49 of set 5 | City number: 2092164 City name: Lorengau
# Record 0 of set 6 | City number: 6148373 City name: Sioux Lookout
# Record 1 of set 6 | City number: 3374083 City name: Bathsheba
# Record 2 of set 6 | City number: 2269142 City name: Colares
# Record 3 of set 6 | City number: 295277 City name: Eilat
# Record 4 of set 6 | City number: 5954718 City name: Flin Flon
# Record 5 of set 6 | City number: 3429594 City name: Reconquista
# Record 6 of set 6 | City number: 3389822 City name: Salinópolis
# Record 7 of set 6 | City number: 7372400 City name: Weihe
# Record 8 of set 6 | City number: 4033557 City name: Tautira
# Record 9 of set 6 | City number: 2123278 City name: Mil'kovo
# Record 10 of set 6 | City number: 5611730 City name: Weiser
# Record 11 of set 6 | City number: 3230781 City name: Hella
# Record 12 of set 6 | City number: 543508 City name: Kovdor
# Record 13 of set 6 | City number: 3421982 City name: Maniitsoq
# Record 14 of set 6 | City number: 4944903 City name: Nantucket
# Record 15 of set 6 | City number: 1586443 City name: Ca Mau
# Record 16 of set 6 | City number: 3372783 City name: Ponta Delgada
# Record 17 of set 6 | City number: 60019 City name: Eyl
# Record 18 of set 6 | City number: 2630299 City name: Hofn
# Record 19 of set 6 | City number: 1272639 City name: Dīg
# Record 20 of set 6 | City number: 2429605 City name: Koumra
# Record 21 of set 6 | City number: 2122262 City name: Palana
# Record 22 of set 6 | City number: 2181625 City name: Te Anau
# Record 23 of set 6 | City number: 6620339 City name: Karratha
# Record 24 of set 6 | City number: 2208248 City name: Kaitangata
# Record 25 of set 6 | City number: 535113 City name: Lipin Bor
# Record 26 of set 6 | City number: 2236967 City name: Soyo
# Record 27 of set 6 | City number: 2377457 City name: Nouadhibou
# Record 28 of set 6 | City number: 2022572 City name: Khatanga
# Record 29 of set 6 | City number: 5975004 City name: High Level
# Record 30 of set 6 | City number: 2063042 City name: Port Hedland
# Record 31 of set 6 | City number: 2074865 City name: Carnarvon
# Record 32 of set 6 | City number: 1804430 City name: Lanzhou
# tsihombe not found. Skipping..
# Record 34 of set 6 | City number: 2156643 City name: Mount Gambier
# Record 35 of set 6 | City number: 1264976 City name: Leh
# Record 36 of set 6 | City number: 2136825 City name: Isangel
# Record 37 of set 6 | City number: 1645528 City name: Denpasar
# Record 38 of set 6 | City number: 3514868 City name: Valle Hermoso
# Record 39 of set 6 | City number: 4012707 City name: Cosalá
# Record 40 of set 6 | City number: 3427761 City name: Tigre
# Record 41 of set 6 | City number: 4033543 City name: Teahupoo
# Record 42 of set 6 | City number: 4764127 City name: Highland Springs
# Record 43 of set 6 | City number: 3019766 City name: La Baule-Escoublac
# Record 44 of set 6 | City number: 1783934 City name: Shangqiu
# Record 45 of set 6 | City number: 2036536 City name: Minzhu
# Record 46 of set 6 | City number: 3894426 City name: Coyhaique
# Record 47 of set 6 | City number: 2618795 City name: Klaksvík
# Record 48 of set 6 | City number: 3393692 City name: Itarema
# Record 49 of set 6 | City number: 2961459 City name: Skibbereen
# Record 0 of set 7 | City number: 1684245 City name: Tagusao
# Record 1 of set 7 | City number: 1633034 City name: Palu
# Record 2 of set 7 | City number: 1337612 City name: Dhidhdhoo
# Record 3 of set 7 | City number: 3698359 City name: Chicama
# Record 4 of set 7 | City number: 339448 City name: Dembī Dolo
# Record 5 of set 7 | City number: 1174451 City name: Keti Bandar
# Record 6 of set 7 | City number: 3984997 City name: San Quintín
# Record 7 of set 7 | City number: 2537763 City name: Salé
# Record 8 of set 7 | City number: 1267390 City name: Kavaratti
# Record 9 of set 7 | City number: 3354071 City name: Oranjemund
# Record 10 of set 7 | City number: 110690 City name: Faya
# Record 11 of set 7 | City number: 2170577 City name: Cooma
# Record 12 of set 7 | City number: 304797 City name: Mardin
# Record 13 of set 7 | City number: 4845585 City name: Westport
# Record 14 of set 7 | City number: 481900 City name: Tpig
# illoqqortoormiut not found. Skipping..
# Record 16 of set 7 | City number: 3439189 City name: Capitán Bado
# Record 17 of set 7 | City number: 2094027 City name: Kieta
# Record 18 of set 7 | City number: 4727756 City name: Seguin
# Record 19 of set 7 | City number: 5368335 City name: Los Altos
# Record 20 of set 7 | City number: 172515 City name: Abu Samrah
# Record 21 of set 7 | City number: 4176380 City name: Venice
# Record 22 of set 7 | City number: 118743 City name: Rasht
# Record 23 of set 7 | City number: 1819729 City name: Hong Kong
# Record 24 of set 7 | City number: 3526756 City name: Isla Mujeres
# Record 25 of set 7 | City number: 159071 City name: Iringa
# Record 26 of set 7 | City number: 1650434 City name: Bambanglipuro
# Record 27 of set 7 | City number: 1214488 City name: Meulaboh
# Record 28 of set 7 | City number: 5127305 City name: Monroe
# Record 29 of set 7 | City number: 3131824 City name: Vigrestad
# kadykchan not found. Skipping..
# balimo not found. Skipping..
# Record 32 of set 7 | City number: 5563839 City name: Fortuna
# Record 33 of set 7 | City number: 2122574 City name: Ola
# Record 34 of set 7 | City number: 3460064 City name: Jatai
# Record 35 of set 7 | City number: 10722858 City name: Forsytheganj
# Record 36 of set 7 | City number: 575480 City name: Bogovarovo
# Record 37 of set 7 | City number: 1635815 City name: Maumere
# Record 38 of set 7 | City number: 3361934 City name: Saldanha
# Record 39 of set 7 | City number: 3662761 City name: Porto Walter
# Record 40 of set 7 | City number: 1242110 City name: Kalmunai
# Record 41 of set 7 | City number: 2152659 City name: Port Macquarie
# Record 42 of set 7 | City number: 1684803 City name: Tabuk
# Record 43 of set 7 | City number: 2186363 City name: Muriwai Beach
# Record 44 of set 7 | City number: 3448455 City name: São Miguel do Araguaia
# Record 45 of set 7 | City number: 6164499 City name: The Pas
# Record 46 of set 7 | City number: 4499379 City name: Wilmington
# tumannyy not found. Skipping..
# Record 48 of set 7 | City number: 3374333 City name: Praia
# Record 49 of set 7 | City number: 1258731 City name: Rāmānuj Ganj
# Record 0 of set 8 | City number: 2640377 City name: Penzance
# Record 1 of set 8 | City number: 3115824 City name: Muros
# Record 2 of set 8 | City number: 1512019 City name: Aksarka
# Record 3 of set 8 | City number: 1249931 City name: Beruwala
# Record 4 of set 8 | City number: 140463 City name: Birjand
# Record 5 of set 8 | City number: 575521 City name: Bogorodskoye
# Record 6 of set 8 | City number: 5861897 City name: Fairbanks
# Record 7 of set 8 | City number: 1260045 City name: Patti
# Record 8 of set 8 | City number: 3070122 City name: Náchod
# Record 9 of set 8 | City number: 1797945 City name: Qingyuan
# Record 10 of set 8 | City number: 3521894 City name: Paredon
# Record 11 of set 8 | City number: 5849297 City name: Kīhei
# Record 12 of set 8 | City number: 2112802 City name: Hasaki
# nizhneyansk not found. Skipping..
# Record 14 of set 8 | City number: 2070998 City name: Geraldton
# Record 15 of set 8 | City number: 2028164 City name: Deputatsky
# Record 16 of set 8 | City number: 2120769 City name: Talaya
# Record 17 of set 8 | City number: 2122614 City name: Ekhabi
# Record 18 of set 8 | City number: 3943626 City name: Chivay
# Record 19 of set 8 | City number: 2028462 City name: Ulaanbaatar
# chagda not found. Skipping..
# Record 21 of set 8 | City number: 5515743 City name: Guymon
# Record 22 of set 8 | City number: 1529376 City name: Korla
# Record 23 of set 8 | City number: 5972762 City name: Hay River
# Record 24 of set 8 | City number: 1630723 City name: Poso
# Record 25 of set 8 | City number: 58933 City name: Garoowe
# Record 26 of set 8 | City number: 6323121 City name: Florianópolis
# Record 27 of set 8 | City number: 4016734 City name: Bucerías
# Record 28 of set 8 | City number: 5392967 City name: Santa Barbara
# taburi not found. Skipping..
# Record 30 of set 8 | City number: 1490042 City name: Tashtagol
# Record 31 of set 8 | City number: 3928317 City name: Lircay
# Record 32 of set 8 | City number: 2303611 City name: Esim
# Record 33 of set 8 | City number: 5110092 City name: Brewster
# Record 34 of set 8 | City number: 2175403 City name: Blackwater
# Record 35 of set 8 | City number: 3146508 City name: Malm
# Record 36 of set 8 | City number: 5044290 City name: Saint Anthony
# zhitikara not found. Skipping..
# Record 38 of set 8 | City number: 478050 City name: Ust'-Kulom
# Record 39 of set 8 | City number: 3356832 City name: Henties Bay
# Record 40 of set 8 | City number: 3386213 City name: Touros
# bur gabo not found. Skipping..
# Record 42 of set 8 | City number: 2527087 City name: Tiznit Province
# Record 43 of set 8 | City number: 2013918 City name: Ust-Maya
# Record 44 of set 8 | City number: 2025456 City name: Chernyshevskiy
# Record 45 of set 8 | City number: 3663684 City name: Lábrea
# Record 46 of set 8 | City number: 1687894 City name: Santa Rosa
# Record 47 of set 8 | City number: 1052373 City name: Beira
# Record 48 of set 8 | City number: 3382160 City name: Cayenne
# westpunt not found. Skipping..
# Record 0 of set 9 | City number: 3628473 City name: San Cristobal
# Record 1 of set 9 | City number: 2121025 City name: Srednekolymsk
# Record 2 of set 9 | City number: 5710360 City name: Winnemucca
# Record 3 of set 9 | City number: 1278969 City name: Along
# Record 4 of set 9 | City number: 1257242 City name: Sārangarh
# Record 5 of set 9 | City number: 363619 City name: Yei
# Record 6 of set 9 | City number: 934649 City name: Cap Malheureux
# Record 7 of set 9 | City number: 3456248 City name: Nortelândia
# Record 8 of set 9 | City number: 1735106 City name: George Town
# Record 9 of set 9 | City number: 778707 City name: Mehamn
# Record 10 of set 9 | City number: 1797535 City name: Qiongshan
# Record 11 of set 9 | City number: 108410 City name: Riyadh
# Record 12 of set 9 | City number: 1040652 City name: Maputo
# Record 13 of set 9 | City number: 2173911 City name: Broken Hill
# Record 14 of set 9 | City number: 2015852 City name: Svetlaya
# Record 15 of set 9 | City number: 6162949 City name: Terrace
# Record 16 of set 9 | City number: 6176823 City name: Waterloo
# jarjis not found. Skipping..
# Record 18 of set 9 | City number: 2541479 City name: Nador
# Record 19 of set 9 | City number: 3932145 City name: Pisco
# Record 20 of set 9 | City number: 2738381 City name: Lata
# Record 21 of set 9 | City number: 3667158 City name: Tierralta
# Record 22 of set 9 | City number: 2139521 City name: Noumea
# Record 23 of set 9 | City number: 523392 City name: Naryan-Mar
# Record 24 of set 9 | City number: 371466 City name: Leer
# Record 25 of set 9 | City number: 6111696 City name: Port-Cartier
# Record 26 of set 9 | City number: 609924 City name: Emba
# Record 27 of set 9 | City number: 3452900 City name: Porto Belo
# Record 28 of set 9 | City number: 3421719 City name: Narsaq
# Record 29 of set 9 | City number: 2360541 City name: Gayéri
# Record 30 of set 9 | City number: 2374583 City name: Bubaque
# Record 31 of set 9 | City number: 5686121 City name: Whitefish
# Record 32 of set 9 | City number: 2032614 City name: Baruun-Urt
# Record 33 of set 9 | City number: 2400547 City name: Gamba
# Record 34 of set 9 | City number: 5554428 City name: Ketchikan
# Record 35 of set 9 | City number: 2180815 City name: Tuatapere
# Record 36 of set 9 | City number: 2171099 City name: Codrington
# Record 37 of set 9 | City number: 367544 City name: Sawākin
# Record 38 of set 9 | City number: 2643044 City name: Margate
# Record 39 of set 9 | City number: 2324433 City name: Abonnema
# Record 40 of set 9 | City number: 545467 City name: Konëvo
# Record 41 of set 9 | City number: 3893726 City name: Constitución
# Record 42 of set 9 | City number: 477940 City name: Ust-Tsilma
# Record 43 of set 9 | City number: 1806408 City name: Yangjiang
# Record 44 of set 9 | City number: 1528998 City name: Yumen
# Record 45 of set 9 | City number: 2669047 City name: Timrå
# Record 46 of set 9 | City number: 3138076 City name: Snåase
# Record 47 of set 9 | City number: 4021858 City name: Guerrero Negro
# Record 48 of set 9 | City number: 2126199 City name: Cherskiy
# Record 49 of set 9 | City number: 2297810 City name: Mumford
# Record 0 of set 10 | City number: 1529660 City name: Aksu
# Record 1 of set 10 | City number: 5197850 City name: Lewistown
# Record 2 of set 10 | City number: 371745 City name: Kutum
# Record 3 of set 10 | City number: 5134295 City name: Rome
# Record 4 of set 10 | City number: 6089245 City name: Norman Wells
# Record 5 of set 10 | City number: 2296606 City name: Obuasi
# Record 6 of set 10 | City number: 6111862 City name: Port Hardy
# lolua not found. Skipping..
# Record 8 of set 10 | City number: 5380420 City name: Pacifica
# Record 9 of set 10 | City number: 4868410 City name: Muscatine
# Record 10 of set 10 | City number: 985011 City name: Lady Frere
# dolbeau not found. Skipping..
# Record 12 of set 10 | City number: 4036284 City name: Alofi
# Record 13 of set 10 | City number: 1252692 City name: Zamānia
# Record 14 of set 10 | City number: 3923570 City name: Atocha
# Record 15 of set 10 | City number: 1493224 City name: Salair
# Record 16 of set 10 | City number: 4898433 City name: Kewanee
# Record 17 of set 10 | City number: 3461370 City name: Imbituba
# Record 18 of set 10 | City number: 3838233 City name: Salta
# Record 19 of set 10 | City number: 3520994 City name: Puerto Escondido
# Record 20 of set 10 | City number: 2206874 City name: Waipawa
# Record 21 of set 10 | City number: 2525362 City name: Carbonia
# marcona not found. Skipping..
# Record 23 of set 10 | City number: 6096551 City name: Pangnirtung
# Record 24 of set 10 | City number: 4013679 City name: Coahuayana Viejo
# Record 25 of set 10 | City number: 895061 City name: Bindura
# Record 26 of set 10 | City number: 605155 City name: Kiruna
# Record 27 of set 10 | City number: 3423146 City name: Ilulissat
# sumbawa not found. Skipping..
# Record 29 of set 10 | City number: 2663536 City name: Vaxjo
# Record 30 of set 10 | City number: 3355672 City name: Lüderitz
# Record 31 of set 10 | City number: 4513583 City name: Hamilton
# Record 32 of set 10 | City number: 152570 City name: Muleba
# Record 33 of set 10 | City number: 5097801 City name: Fairview
# Record 34 of set 10 | City number: 1809858 City name: Guangzhou
# Record 35 of set 10 | City number: 531979 City name: Maksatikha
# Record 36 of set 10 | City number: 3899695 City name: Ancud
# Record 37 of set 10 | City number: 1802618 City name: Longhua
# Record 38 of set 10 | City number: 5503914 City name: Fallon
# Record 39 of set 10 | City number: 3691954 City name: Sechura
# Record 40 of set 10 | City number: 1168700 City name: Ormara
# Record 41 of set 10 | City number: 2129766 City name: Kamiiso
# Record 42 of set 10 | City number: 3466980 City name: Caravelas
# mendahara not found. Skipping..
# Record 44 of set 10 | City number: 5546220 City name: Saint George
# bargal not found. Skipping..
# Record 46 of set 10 | City number: 1495626 City name: Pangody
# Record 47 of set 10 | City number: 2729907 City name: Longyearbyen
# Record 48 of set 10 | City number: 610298 City name: Beyneu
# Record 49 of set 10 | City number: 3868626 City name: Valparaíso
# Record 0 of set 11 | City number: 470905 City name: Vuktyl
# Record 1 of set 11 | City number: 103630 City name: Najrān
# Record 2 of set 11 | City number: 5703673 City name: Elko
# toliary not found. Skipping..
# Record 4 of set 11 | City number: 1058381 City name: Morondava
# Record 5 of set 11 | City number: 1801669 City name: Luyang
# Record 6 of set 11 | City number: 5802570 City name: Marysville
# tidore not found. Skipping..
# Record 8 of set 11 | City number: 5126209 City name: Mastic Beach
# Record 9 of set 11 | City number: 3697838 City name: Contamana
# Record 10 of set 11 | City number: 3545981 City name: Niquero
# Record 11 of set 11 | City number: 5530022 City name: San Angelo
# Record 12 of set 11 | City number: 6078372 City name: Moose Factory
# Record 13 of set 11 | City number: 4031637 City name: Lavrentiya
# Record 14 of set 11 | City number: 2123814 City name: Leningradskiy
# Record 15 of set 11 | City number: 1861795 City name: Ikeda
# Record 16 of set 11 | City number: 3491161 City name: Bull Savanna
# Record 17 of set 11 | City number: 1278768 City name: Āmli
# Record 18 of set 11 | City number: 1271374 City name: Ghansor
# Record 19 of set 11 | City number: 726524 City name: Svoge
# ust-kamchatsk not found. Skipping..
# Record 21 of set 11 | City number: 1798760 City name: Pingliang
# Record 22 of set 11 | City number: 2172797 City name: Cairns
# Record 23 of set 11 | City number: 4676740 City name: Brownsville
# Record 24 of set 11 | City number: 3171771 City name: Ovada
# Record 25 of set 11 | City number: 1636308 City name: Manokwari
# Record 26 of set 11 | City number: 1726449 City name: Basco
# Record 27 of set 11 | City number: 783754 City name: Albania
# Record 28 of set 11 | City number: 1489822 City name: Tegul'det
# Record 29 of set 11 | City number: 2449893 City name: Tessalit
# Record 30 of set 11 | City number: 1529484 City name: Kumul
# Record 31 of set 11 | City number: 2269449 City name: Caxias
# Record 32 of set 11 | City number: 64814 City name: Bandarbeyla
# Record 33 of set 11 | City number: 6316343 City name: Alta Floresta
# Record 34 of set 11 | City number: 2171722 City name: Charters Towers
# Record 35 of set 11 | City number: 2304548 City name: Anloga
# Record 36 of set 11 | City number: 5920288 City name: Charlottetown
# Record 37 of set 11 | City number: 2654970 City name: Brae
# Record 38 of set 11 | City number: 964712 City name: Plettenberg Bay
# arandelovac not found. Skipping..
# Record 40 of set 11 | City number: 5977046 City name: Hornepayne
# Record 41 of set 11 | City number: 2177069 City name: Ballina
# Record 42 of set 11 | City number: 3444176 City name: Roboré
# Record 43 of set 11 | City number: 934479 City name: Grand Gaube
# Record 44 of set 11 | City number: 5478673 City name: Meadow Lake
# Record 45 of set 11 | City number: 1509844 City name: Boguchany
# Record 46 of set 11 | City number: 5233742 City name: Bennington
# Record 47 of set 11 | City number: 5530932 City name: Socorro
# hvammstangi not found. Skipping..
# Record 49 of set 11 | City number: 1792947 City name: Tianjin
# Record 0 of set 12 | City number: 5142056 City name: Utica
# urdzhar not found. Skipping..
# saryshagan not found. Skipping..
# Record 3 of set 12 | City number: 2019935 City name: Mnogovershinnyy
# Record 4 of set 12 | City number: 5859699 City name: College
# Record 5 of set 12 | City number: 259265 City name: Koróni
# Record 6 of set 12 | City number: 2240449 City name: Luanda
# Record 7 of set 12 | City number: 1733697 City name: Semporna
# Record 8 of set 12 | City number: 5367788 City name: Lompoc
# Record 9 of set 12 | City number: 2112444 City name: Kamaishi
# gangotri not found. Skipping..
# Record 11 of set 12 | City number: 88319 City name: Benghazi
# Record 12 of set 12 | City number: 730518 City name: Kavarna
# karaul not found. Skipping..
# Record 14 of set 12 | City number: 2109528 City name: Buala
# Record 15 of set 12 | City number: 1337605 City name: Mahibadhoo
# Record 16 of set 12 | City number: 3141310 City name: Rørvik
# Record 17 of set 12 | City number: 4032420 City name: Neiafu
# Record 18 of set 12 | City number: 2035325 City name: Qinggang
# Record 19 of set 12 | City number: 1488414 City name: Urengoy
# Record 20 of set 12 | City number: 2071860 City name: Esperance
# Record 21 of set 12 | City number: 1162738 City name: Jhang
# Record 22 of set 12 | City number: 3421319 City name: Nuuk
# Record 23 of set 12 | City number: 3522526 City name: Nuevo Progreso
# Record 24 of set 12 | City number: 3567655 City name: Batabanó
# Record 25 of set 12 | City number: 2018735 City name: Nyurba
# Record 26 of set 12 | City number: 3392126 City name: Pilar
# Record 27 of set 12 | City number: 5870133 City name: Nome
# Record 28 of set 12 | City number: 3136690 City name: Stokmarknes
# Record 29 of set 12 | City number: 1500399 City name: Lokosovo
# Record 30 of set 12 | City number: 3733380 City name: Campoverde
# Record 31 of set 12 | City number: 4549638 City name: Rogers
# Record 32 of set 12 | City number: 935214 City name: Saint-Pierre
# Record 33 of set 12 | City number: 1847947 City name: Shingū
# Record 34 of set 12 | City number: 674735 City name: Lipniţa
# one hundred mile house not found. Skipping..
# Record 36 of set 12 | City number: 6067472 City name: Marystown
# Record 37 of set 12 | City number: 4033077 City name: Vaitape
# Record 38 of set 12 | City number: 156974 City name: Kisesa
# Record 39 of set 12 | City number: 3608248 City name: La Ceiba
# Record 40 of set 12 | City number: 359792 City name: Aswān
# Record 41 of set 12 | City number: 1067565 City name: Beloha
# grand centre not found. Skipping..
# Record 43 of set 12 | City number: 2127202 City name: Anadyr
# Record 44 of set 12 | City number: 2090021 City name: Namatanai
# Record 45 of set 12 | City number: 2015701 City name: Taksimo
# Record 46 of set 12 | City number: 1271717 City name: Gāndhīdhām
# Record 47 of set 12 | City number: 2016216 City name: Sosnovo-Ozerskoye
# Record 48 of set 12 | City number: 1529102 City name: Ürümqi
# Record 49 of set 12 | City number: 1489656 City name: Teya
# Record 0 of set 13 | City number: 1516048 City name: Khovd
# kuche not found. Skipping..
# Record 2 of set 13 | City number: 3988392 City name: Rosarito
# Record 3 of set 13 | City number: 5779036 City name: North Ogden
# Record 4 of set 13 | City number: 118826 City name: Rāmhormoz
# aflu not found. Skipping..
# Record 6 of set 13 | City number: 1640902 City name: Kawalu
# Record 7 of set 13 | City number: 2636790 City name: Stornoway
# Record 8 of set 13 | City number: 2023584 City name: Imeni Poliny Osipenko
# Record 9 of set 13 | City number: 2084442 City name: Vanimo
# Record 10 of set 13 | City number: 3137469 City name: Sørland
# Record 11 of set 13 | City number: 4755280 City name: Danville
# -----------------------------------
# Data Retrieval Complete
# -----------------------------------

# %% [markdown]
# ## Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Retrive data for the DataFrame
city_n = []
cloudiness =[]
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

for city in cities_with_data:
    city_url = f"{url}{city}&units=imperial"
    response = requests.get(city_url).json()
    city_n.append(response["name"])
    cloudiness.append(response["clouds"]["all"])
    country.append(response["sys"]["country"])
    date.append(response["dt"])
    humidity.append(response["main"]["humidity"])
    lat.append(response["coord"]["lat"])
    lng.append(response["coord"]["lon"])
    max_temp.append(response["main"]["temp_max"])
    wind_speed.append(response["wind"]["speed"])

#Create the DataFrame
weather_df = pd.DataFrame({"City": city_n, "Cloudiness": cloudiness, "Country": country, "Date": date, "Humidity": humidity,
                          "Lat": lat, "Lng": lng, "Max Temp": max_temp, "Wind Speed": wind_speed})
# Display the DataFrame
weather_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Ushuaia          75      AR  1603988482        81 -54.80  -68.30
# 1      Contai          73      IN  1603988482        75  21.78   87.75
# 2       Airai          14      TL  1603988483       100  -8.93  125.41
# 3  Nikolskoye          20      RU  1603988451        87  59.70   30.79
# 4  Khedbrahma           0      IN  1603988484        29  24.03   73.05
#
#    Max Temp  Wind Speed
# 0     46.40       29.97
# 1     75.54        5.84
# 2     61.57        0.89
# 3     51.01        3.33
# 4     75.94        1.54

# %%
#Export the city data into a .csv
weather_df.to_csv(output_data_file)

# %%
pd.to_datetime(weather_df["Date"])
# Out:
# 0     1970-01-01 00:00:01.603988482
# 1     1970-01-01 00:00:01.603988482
# 2     1970-01-01 00:00:01.603988483
# 3     1970-01-01 00:00:01.603988451
# 4     1970-01-01 00:00:01.603988484
#                    ...
# 556   1970-01-01 00:00:01.603988677
# 557   1970-01-01 00:00:01.603988677
# 558   1970-01-01 00:00:01.603988678
# 559   1970-01-01 00:00:01.603988678
# 560   1970-01-01 00:00:01.603988525
# Name: Date, Length: 561, dtype: datetime64[ns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Max Temp"], facecolors="salmon", edgecolor="black")
plt.title("City Latitude vs. Max Temperature (1970-01-01)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("output_data/Lat_vs_MaxTemp.png")
plt.show()

# %% [markdown]
# This code is analyzing the relationship between the maximum temperature from each city versus its Latitude.

# %% [markdown]
# ###  Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Humidity"], facecolors="salmon", edgecolor="black")
plt.title("City Latitude vs. Humidity (1970-01-01)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("output_data/Lat_vs_Humidity.png")
plt.show()

# %% [markdown]
# This code is analyzing the relationship between the humidity from each city versus its Latitude.

# %% [markdown]
# ###  Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"], facecolors="salmon", edgecolor="black")
plt.title("City Latitude vs. Cloudiness (1970-01-01)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("output_data/Lat_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# This code is analyzing the relationship between the cloudiness from each city versus its Latitude.

# %% [markdown]
# ###  Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"], facecolors="salmon", edgecolor="black")
plt.title("City Latitude vs. Wind Speed (1970-01-01)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("output_data/Lat_vs_WindSpeed.png")
plt.show()

# %% [markdown]
# This code is analyzing the relationship between the wind speed from each city versus its Latitude.

# %% [markdown]
# ##  Linear Regression

# %%
# Create Northern Hemisphere DataFrame
city_n = []
cloudiness =[]
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

for city in cities_with_data:
    city_url = f"{url}{city}&units=imperial"
    response = requests.get(city_url).json()
    if (response["coord"]["lat"] >= 0):
        city_n.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
northern_df = pd.DataFrame({"City": city_n, "Cloudiness": cloudiness, "Country": country, "Date": date, "Humidity": humidity,
                          "Lat": lat, "Lng": lng, "Max Temp": max_temp, "Wind Speed": wind_speed})
northern_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          Contai          79      IN  1603990261        76  21.78   87.75
# 1      Nikolskoye          75      RU  1603990261        87  59.70   30.79
# 2      Khedbrahma           0      IN  1603990262        29  24.03   73.05
# 3        Ust-Nera         100      RU  1603990262        88  64.57  143.20
# 4  Vestmannaeyjar          75      IS  1603990264        87  63.44  -20.27
#
#    Max Temp  Wind Speed
# 0     75.00        5.59
# 1     51.01        4.47
# 2     74.86        2.06
# 3      7.93        1.43
# 4     46.40       21.92

# %%
# Create Southern Hemisphere DataFrame
city_n = []
cloudiness =[]
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

for city in cities_with_data:
    city_url = f"{url}{city}&units=imperial"
    response = requests.get(city_url).json()
    if (response["coord"]["lat"] < 0):
        city_n.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
southern_df = pd.DataFrame({"City": city_n, "Cloudiness": cloudiness, "Country": country, "Date": date, "Humidity": humidity,
                          "Lat": lat, "Lng": lng, "Max Temp": max_temp, "Wind Speed": wind_speed})
southern_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Ushuaia          75      AR  1603989661        81 -54.80  -68.30
# 1       Airai          23      TL  1603990261       100  -8.93  125.41
# 2  Bredasdorp          97      ZA  1603990487        65 -34.53   20.04
# 3    Souillac          45      MU  1603990263        66 -20.52   57.52
# 4     Mataura          78      NZ  1603990263        92 -46.19  168.86
#
#    Max Temp  Wind Speed
# 0     46.40       34.45
# 1     61.20        1.05
# 2     55.99        5.01
# 3     71.01        8.99
# 4     52.00        1.99

# %% [markdown]
# ### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Calculate the linear regression model Northern Hemisphere - Max Temp vs. Latitude
x_values = northern_df["Lat"]
y_values = northern_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
predict = slope * x_values + intercept
northern_df["Predict"] = predict
plt.scatter(x_values, y_values, facecolors="thistle", edgecolor="black")
plt.plot(x_values, northern_df["Predict"])
plt.annotate(line_eq, (5,20))
plt.title("Latitude vs. Max Temperature of Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.show()
# Out:
# The r-squared is: 0.7724798057760065

# %% [markdown]
# ### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Calculate the linear regression model Southern Hemisphere - Max Temp vs. Latitude
x_values = southern_df["Lat"]
y_values = southern_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
predict = slope * x_values + intercept
southern_df["Predict"] = predict
plt.scatter(x_values, y_values, facecolors="thistle", edgecolor="black")
plt.plot(x_values, southern_df["Predict"])
plt.annotate(line_eq, (-52,80))
plt.title("Latitude vs. Max Temperature of Southern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.show()
# Out:
# The r-squared is: 0.5850874252663847

# %% [markdown]
# This code is analyzing the relationship between the maximum temperature from each city versus the northern hemisphere and southern hemisphere.
# * In the northern hemisphere the maximum temperature is warmer close to latitude 0 and it decreases as the latitude increases with an equation of y = -1.09x + 96.27 tending to be 0°F according to the ecuation when the latitude is 88.32.
# * In the southern hemisphere the maximum temperature is also warmer close to latitude 0 and it decreases as the latitude decreases with the equation y = 0.68x + 85.65  and acording to it whe the latitude is -90 the maximum temperature tends to be 24.45°F

# %% [markdown]
# ### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Calculate the linear regression model Northern Hemisphere - Humidity vs. Latitude
x_values = northern_df["Lat"]
y_values = northern_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
predict = slope * x_values + intercept
northern_df["Predict"] = predict
plt.scatter(x_values, y_values, facecolors="thistle", edgecolor="black")
plt.plot(x_values, northern_df["Predict"])
plt.annotate(line_eq, (50,20))
plt.title("Latitude vs. Humidity of Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.show()
# Out:
# The r-squared is: 0.19642653164948248

# %% [markdown]
# ### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Calculate the linear regression model Southern Hemisphere - Humidity vs. Latitude
x_values = southern_df["Lat"]
y_values = southern_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
predict = slope * x_values + intercept
southern_df["Predict"] = predict
plt.scatter(x_values, y_values, facecolors="thistle", edgecolor="black")
plt.plot(x_values, southern_df["Predict"])
plt.annotate(line_eq, (-56,30))
plt.title("Latitude vs. Humidity of Southern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.show()
# Out:
# The r-squared is: 0.00017588194014204545

# %% [markdown]
# This code is analyzing the relationship between the percentage of humidity from each city versus the northern hemisphere and southern hemisphere.
#
# * In the northern hemisphere the humidity tends to be greater as it gets further from latitude 0 but when latitude is close to 0 it tends to be more diverese. The equation for the linear regression is y = 0.39x + 57.96
# * In the southern hemisphere the humidity seems diverse no matter in wich latitude you are looking at, so the slope of the linear regresion is smaller for the southern hemisphere than it was for the northern hemisphere, resulting in an equation y = -0.2x + 67.35, that indicates that the humidity tends to be a little gratter when the latitude is smaller.

# %% [markdown]
# ### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Calculate the linear regression model Northern Hemisphere - Cloudiness vs. Latitude
x_values = northern_df["Lat"]
y_values = northern_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
predict = slope * x_values + intercept
northern_df["Predict"] = predict
plt.scatter(x_values, y_values, facecolors="thistle", edgecolor="black")
plt.plot(x_values, northern_df["Predict"])
plt.annotate(line_eq, (60,10))
plt.title("Latitude vs. Cloudiness of Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.show()
# Out:
# The r-squared is: 0.0665381558792954

# %% [markdown]
# ### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Calculate the linear regression model Southern Hemisphere - Cloudiness vs. Latitude
x_values = southern_df["Lat"]
y_values = southern_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
predict = slope * x_values + intercept
southern_df["Predict"] = predict
plt.scatter(x_values, y_values, facecolors="thistle", edgecolor="black")
plt.plot(x_values, southern_df["Predict"])
plt.annotate(line_eq, (-55,50))
plt.title("Latitude vs. Cloudiness of Southern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.show()
# Out:
# The r-squared is: 0.0006741604994016255

# %% [markdown]
# This code is analyzing the relationship between the percentage of cloudiness from each city versus the northern hemisphere and southern hemisphere.
#
# * According to the scatter plot in the northern hemisphere the cloudiness seems to be very diverse in the different latitudes, but the linear regression equation (y = 0.36x + 36.71) has a small slope indicating thet the percentage of cloudiness tends to increase a little as the latitude increases.
# * In the southern hemisphere the cloudiness seems to be the same case as in the northern hemisphere, but in this case the linear regression equation (y = 0.28x + 57.84) indicates that the percentage of cloudiness tends to decrease a little as the latitude decreasses.

# %% [markdown]
# ### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Calculate the linear regression model Northern Hemisphere - Wind Speed vs. Latitude
x_values = northern_df["Lat"]
y_values = northern_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
predict = slope * x_values + intercept
northern_df["Predict"] = predict
plt.scatter(x_values, y_values, facecolors="thistle", edgecolor="black")
plt.plot(x_values, northern_df["Predict"])
plt.annotate(line_eq, (25,32))
plt.title("Latitude vs. Wind Speed of Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.show()
# Out:
# The r-squared is: 0.017493324286629666

# %% [markdown]
# ### Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Calculate the linear regression model Southern Hemisphere - Wind Speed vs. Latitude
x_values = southern_df["Lat"]
y_values = southern_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(f"The r-squared is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
predict = slope * x_values + intercept
southern_df["Predict"] = predict
plt.scatter(x_values, y_values, facecolors="thistle", edgecolor="black")
plt.plot(x_values, southern_df["Predict"])
plt.annotate(line_eq, (-49,22))
plt.title("Latitude vs. Wind Speed of Southern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.show()
# Out:
# The r-squared is: 0.04943143692686532

# %% [markdown]
# This code is analyzing the relationship between the wind speed from each city versus the northern hemisphere and southern hemisphere.
#
# * According to the scatter plot in the northern hemisphere the wind speed seems to be similar in the different latitudes, and also the linear regression equation y = 0.03x + 5.99 has a very small slope indicating thet the wind speed tends to increase just a little as the latitude increases.
# * In the southern hemisphere the wind speed seems to be pretty similar as in the northern hemisphere, but in this case the linear regression equation is y = -0.04x + 7.2 indicating that the wind speed tends to increase a little as the latitude decreasses.
